# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-Vishwakarma-GH/Himanshu/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
final = pd.read_csv('https://raw.githubusercontent.com/ethanweed/pythonbook/main/Data/afl_margins.csv')
print(type(final))
#Reading The Online Csv File Using pandas And Printing The Type Of data It Is
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
sns.histplot(final)
#histplot Function To Make A Histogram OF The Above Mention Data
# Out:
# <Axes: ylabel='Count'>

# %%
sns.get_dataset_names() #Listing All The DataSet Names Present In Seaborn Midoule
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
aa = sns.load_dataset('tips')
#Accessing One Of The data Set Names "tips"
print(aa)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
aa.head()
#Printing The First 5 Sequencial Data from the 'tips' Named Data Set
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['total_bill'].plot(kind='hist', bins=20, title='total_bill')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['tip'].plot(kind='hist', bins=20, title='tip')
# ...

# %%
aa.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['total_bill'].plot(kind='hist', bins=20, title='total_bill')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['tip'].plot(kind='hist', bins=20, title='tip')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['size'].plot(kind='hist', bins=20, title='size')
# ...

# %%
np.max(aa['size'])
# Out:
# 6

# %%
sns.boxplot(aa['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(aa)
# Out:
# <Axes: >

# %%
b=sns.load_dataset('iris')
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
print(b.info)
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
print(b['sepal_length'])
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
sns.histplot(b['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(b)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(b,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
c=pd.read_csv('/Credit_Card_Data.csv')
c
# Out:
#               City        DateTime  Card Type Expense Type Gender  Amount
# 0            Delhi  10/29/14 15:30       Gold        Bills      F   82475
# 1   Greater Mumbai  08/22/14 15:30   Platinum        Bills      F   32555
# 2        Bengaluru  08/27/14 15:30     Silver        Bills      F  101738
# 3   Greater Mumbai  04/15/14 15:30  Signature        Bills      F  123424
# 4        Bengaluru  05/05/15 15:30       Gold        Bills      F  171574
# 5            Delhi  08/09/14 15:30     Silver        Bills      F  100036
# 6            Delhi  02/24/15 15:30       Gold        Bills      F  143250
# 7   Greater Mumbai  06/26/14 15:30   Platinum        Bills      F  150980
# 8            Delhi  03/28/14 15:30     Silver        Bills      F  192247
# 9            Delhi  01/09/14 15:30   Platinum        Bills      F   67932
# 10           Delhi  06/22/14 15:30   Platinum        Bills      F  280061
# 11  Greater Mumbai  07/12/13 15:30  Signature        Bills      F  278036
# ...

# %%
#Converting The DateTime Type (Which Is String) Into DateTime Type (Into DateTime Format)
c['DateTime']= pd.to_datetime(c['DateTime'])
# Out:
# <ipython-input-31-e05e48765e35>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   c['DateTime']= pd.to_datetime(c['DateTime'])

# %%
c.info()
c
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          19 non-null     object
#  1   DateTime      19 non-null     datetime64[ns]
#  2   Card Type     19 non-null     object
#  3   Expense Type  19 non-null     object
#  4   Gender        19 non-null     object
#  5   Amount        19 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 1.0+ KB
#               City            DateTime  Card Type Expense Type Gender  Amount
# 0            Delhi 2014-10-29 15:30:00       Gold        Bills      F   82475
# 1   Greater Mumbai 2014-08-22 15:30:00   Platinum        Bills      F   32555
# 2        Bengaluru 2014-08-27 15:30:00     Silver        Bills      F  101738
# 3   Greater Mumbai 2014-04-15 15:30:00  Signature        Bills      F  123424
# ...

# %%
#Now We Will Be trying To Change The Index Of The Dataframes
c.set_index('DateTime', inplace=True)
c
# Out:
#                                City Expense Type  Amount
# DateTime
# 2014-10-29 15:30:00           Delhi        Bills   82475
# 2014-08-22 15:30:00  Greater Mumbai        Bills   32555
# 2014-08-27 15:30:00       Bengaluru        Bills  101738
# 2014-04-15 15:30:00  Greater Mumbai        Bills  123424
# 2015-05-05 15:30:00       Bengaluru        Bills  171574
# 2014-08-09 15:30:00           Delhi        Bills  100036
# 2015-02-24 15:30:00           Delhi        Bills  143250
# 2014-06-26 15:30:00  Greater Mumbai        Bills  150980
# 2014-03-28 15:30:00           Delhi        Bills  192247
# 2014-01-09 15:30:00           Delhi        Bills   67932
# 2014-06-22 15:30:00           Delhi        Bills  280061
# 2013-07-12 15:30:00  Greater Mumbai        Bills  278036
# 2014-07-08 15:30:00  Greater Mumbai        Bills   19226
# 2014-07-27 15:30:00           Delhi        Bills  254359
# 2014-05-08 15:30:00  Greater Mumbai        Bills  302834
# ...
